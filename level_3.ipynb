# %%
import torch
import torchvision
import torchvision.transforms as transforms
import numpy as np
from torch.utils.data import random_split, DataLoader
import torch.nn.functional as F
import torch.nn as nn
import copy
import matplotlib.pyplot as plt


# CNN model definition
def create_lenet():
    model = nn.Sequential(
        nn.Conv2d(1, 6, 5, padding=2),
        nn.ReLU(),
        nn.AvgPool2d(2, stride=2),
        nn.Conv2d(6, 16, 5, padding=0),
        nn.ReLU(),
        nn.AvgPool2d(2, stride=2),
        nn.Flatten(),
        nn.Linear(400, 120),
        nn.ReLU(),
        nn.Linear(120, 84),
        nn.ReLU(),
        nn.Linear(84, 10)
    )
    return model


# Load data (each client will load its own data in a real FL scenario)
def load_data(transform, datasets='MNIST'):

    train_dataset =  torchvision.datasets.MNIST('mnist_data', train=True, download=True, transform=transform)
    test_dataset = torchvision.datasets.MNIST('mnist_data', train=False, download=True, transform=transform)

    return train_dataset, test_dataset


# Split the dataset into 'n_clients' partitions
def partition_dataset(dataset, n_clients=10):
    split_size = len(dataset) // n_clients
    return random_split(dataset, [split_size] * n_clients)


# Client-side local training
def client_update(client_model, optimizer, train_loader, device, epochs=1):
    epoch_losses = []
    client_model.train()
    for epoch in range(epochs):
        running_loss = 0.0
        for data, labels in train_loader:
            data, labels = data.to(device), labels.to(device)
            optimizer.zero_grad()
            output = client_model(data)
            loss = F.cross_entropy(output, labels)
            loss.backward()
            optimizer.step()
            running_loss += loss.item()
    avg_loss = running_loss / len(train_loader)
    epoch_losses.append(avg_loss)

    return epoch_losses  # return list of losses per local epoch

# Function to simulate an evil client sending random updates 
def evil_client_update(client_model):
  for param in client_model.parameters(): 
    param.data = torch.randn_like(param.data)


# Server-side aggregation of client models
import torch

def server_aggregate(global_model, client_models):
    global_dict = global_model.state_dict()
    num_clients = len(client_models)
    threshold = 2.81 # 2.81: 88.8800% 2.80: 81.5000% 2.75: 70.0500 Adjusted threshold

    for k in global_dict.keys():
        client_updates = torch.stack([client_models[i].state_dict()[k] for i in range(num_clients)], 0)
        mean_update = client_updates.mean(0)
        std_update = client_updates.std(0)
        mad = torch.median(torch.abs(client_updates - torch.median(client_updates, 0)[0]), 0)[0]

        for i in range(num_clients):
            deviation_std = torch.abs(client_updates[i] - mean_update) / (std_update + 1e-6)
            deviation_mad = torch.abs(client_updates[i] - mean_update) / (mad + 1e-6)
           
            if torch.any(deviation_std > threshold) and torch.any(deviation_mad > threshold):
                print(f"Client {i} has been detected as malicious or abnormal for parameter {k}.")
                client_updates[i] = mean_update  # Replace abnormal update with the mean update

        global_dict[k] = client_updates.mean(0)  # Aggregate using the mean of filtered updates

    global_model.load_state_dict(global_dict)


# Test model on test dataset
def test_model(model, test_loader, device):
    model.eval()
    correct, total = 0, 0
    with torch.no_grad():
        for data, labels in test_loader:
            data, labels = data.to(device), labels.to(device)
            output = model(data)
            _, predicted = torch.max(output, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
    return 100 * correct / total

# %%
# Federated Learning process

n_clients=10
global_epochs=10
local_epochs=3
evil_clients = 1


device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Set up the data transformation and load dataset

transform = transforms.Compose(
    [transforms.ToTensor(), transforms.Normalize((0.5,), (0.5,))])

train_dataset, test_dataset = load_data(transform)

plt.imshow(train_dataset[0][0][0], cmap='gray')
plt.show()

# Partition the dataset for each client
client_datasets = partition_dataset(train_dataset, n_clients)
client_loaders = [DataLoader(dataset, batch_size=50, shuffle=True)
                  for dataset in client_datasets]
test_loader = DataLoader(test_dataset, batch_size=1000, shuffle=False)

# Initialize global model and client models
global_model = create_lenet().to(device)
client_models = [copy.deepcopy(global_model) for _ in range(n_clients)]

# Optimizers for client models
optimizers = [torch.optim.Adam(model.parameters(), lr=0.001)
              for model in client_models]

# Federated Learning process
global_accuracies = []
client_losses_history = [[] for _ in range(n_clients)]

for global_epoch in range(global_epochs):
    print(f'Global Epoch {global_epoch + 1}/{global_epochs}')

    # Each client trains locally
    for client_idx in range(n_clients):
      if client_idx < evil_clients:
        losses = evil_client_update(client_models[client_idx])
        client_losses_history[client_idx].append(losses)
      else:
        losses = client_update(client_models[client_idx], optimizers[client_idx],
                      client_loaders[client_idx], device, local_epochs)
        client_losses_history[client_idx].append(losses)


    # Server aggregates the models
    server_aggregate(global_model, client_models)

    # Evaluate global model on test dataset
    test_accuracy = test_model(global_model, test_loader, device)
    global_accuracies.append(test_accuracy)
    print(
        f'Global Model Test Accuracy after round {global_epoch + 1}: {test_accuracy:.4f}%')

# Save the final global model
torch.save(global_model.state_dict(), 'malicious_client_federated_model.pth')
print("Federated learning process completed.")
# Out:
# Global Epoch 1/10
# Client 0 has been detected as malicious or abnormal for parameter 0.weight.
# Client 0 has been detected as malicious or abnormal for parameter 0.bias.
# Client 0 has been detected as malicious or abnormal for parameter 3.weight.
# Client 0 has been detected as malicious or abnormal for parameter 3.bias.
# Client 0 has been detected as malicious or abnormal for parameter 7.weight.
# Client 3 has been detected as malicious or abnormal for parameter 7.weight.
# Client 4 has been detected as malicious or abnormal for parameter 7.weight.
# Client 0 has been detected as malicious or abnormal for parameter 7.bias.
# Client 0 has been detected as malicious or abnormal for parameter 9.weight.
# Client 0 has been detected as malicious or abnormal for parameter 9.bias.
# Client 0 has been detected as malicious or abnormal for parameter 11.weight.
# Client 0 has been detected as malicious or abnormal for parameter 11.bias.
# Global Model Test Accuracy after round 1: 88.9200%
# Global Epoch 2/10
# Client 0 has been detected as malicious or abnormal for parameter 0.weight.
# Client 0 has been detected as malicious or abnormal for parameter 0.bias.
# Client 0 has been detected as malicious or abnormal for parameter 3.weight.
# Client 4 has been detected as malicious or abnormal for parameter 3.weight.
# Client 0 has been detected as malicious or abnormal for parameter 3.bias.
# Client 0 has been detected as malicious or abnormal for parameter 7.weight.
# Client 2 has been detected as malicious or abnormal for parameter 7.weight.
# Client 6 has been detected as malicious or abnormal for parameter 7.weight.
# Client 7 has been detected as malicious or abnormal for parameter 7.weight.
# Client 0 has been detected as malicious or abnormal for parameter 7.bias.
# Client 0 has been detected as malicious or abnormal for parameter 9.weight.
# Client 7 has been detected as malicious or abnormal for parameter 9.weight.
# Client 8 has been detected as malicious or abnormal for parameter 9.weight.
# Client 0 has been detected as malicious or abnormal for parameter 9.bias.
# Client 0 has been detected as malicious or abnormal for parameter 11.weight.
# Client 0 has been detected as malicious or abnormal for parameter 11.bias.
# Global Model Test Accuracy after round 2: 88.5000%
# Global Epoch 3/10
# Client 0 has been detected as malicious or abnormal for parameter 0.weight.
# Client 0 has been detected as malicious or abnormal for parameter 0.bias.
# Client 0 has been detected as malicious or abnormal for parameter 3.weight.
# Client 0 has been detected as malicious or abnormal for parameter 3.bias.
# Client 0 has been detected as malicious or abnormal for parameter 7.weight.
# Client 2 has been detected as malicious or abnormal for parameter 7.weight.
# Client 4 has been detected as malicious or abnormal for parameter 7.weight.
# Client 6 has been detected as malicious or abnormal for parameter 7.weight.
# Client 7 has been detected as malicious or abnormal for parameter 7.weight.
# Client 0 has been detected as malicious or abnormal for parameter 7.bias.
# Client 0 has been detected as malicious or abnormal for parameter 9.weight.
# Client 1 has been detected as malicious or abnormal for parameter 9.weight.
# Client 0 has been detected as malicious or abnormal for parameter 9.bias.
# Client 0 has been detected as malicious or abnormal for parameter 11.weight.
# Client 1 has been detected as malicious or abnormal for parameter 11.weight.
# Client 0 has been detected as malicious or abnormal for parameter 11.bias.
# Global Model Test Accuracy after round 3: 87.1300%
# Global Epoch 4/10
# Client 0 has been detected as malicious or abnormal for parameter 0.weight.
# Client 0 has been detected as malicious or abnormal for parameter 0.bias.
# Client 0 has been detected as malicious or abnormal for parameter 3.weight.
# Client 4 has been detected as malicious or abnormal for parameter 3.weight.
# Client 0 has been detected as malicious or abnormal for parameter 3.bias.
# Client 0 has been detected as malicious or abnormal for parameter 7.weight.
# Client 2 has been detected as malicious or abnormal for parameter 7.weight.
# Client 3 has been detected as malicious or abnormal for parameter 7.weight.
# Client 4 has been detected as malicious or abnormal for parameter 7.weight.
# Client 6 has been detected as malicious or abnormal for parameter 7.weight.
# Client 8 has been detected as malicious or abnormal for parameter 7.weight.
# Client 0 has been detected as malicious or abnormal for parameter 7.bias.
# Client 0 has been detected as malicious or abnormal for parameter 9.weight.
# Client 2 has been detected as malicious or abnormal for parameter 9.weight.
# Client 8 has been detected as malicious or abnormal for parameter 9.weight.
# Client 0 has been detected as malicious or abnormal for parameter 9.bias.
# Client 0 has been detected as malicious or abnormal for parameter 11.weight.
# Client 0 has been detected as malicious or abnormal for parameter 11.bias.
# Global Model Test Accuracy after round 4: 82.1300%
# Global Epoch 5/10
# Client 0 has been detected as malicious or abnormal for parameter 0.weight.
# Client 0 has been detected as malicious or abnormal for parameter 0.bias.
# Client 0 has been detected as malicious or abnormal for parameter 3.weight.
# Client 0 has been detected as malicious or abnormal for parameter 3.bias.
# Client 0 has been detected as malicious or abnormal for parameter 7.weight.
# Client 2 has been detected as malicious or abnormal for parameter 7.weight.
# Client 3 has been detected as malicious or abnormal for parameter 7.weight.
# Client 4 has been detected as malicious or abnormal for parameter 7.weight.
# Client 6 has been detected as malicious or abnormal for parameter 7.weight.
# Client 8 has been detected as malicious or abnormal for parameter 7.weight.
# Client 0 has been detected as malicious or abnormal for parameter 7.bias.
# Client 0 has been detected as malicious or abnormal for parameter 9.weight.
# Client 2 has been detected as malicious or abnormal for parameter 9.weight.
# Client 0 has been detected as malicious or abnormal for parameter 9.bias.
# Client 0 has been detected as malicious or abnormal for parameter 11.weight.
# Client 0 has been detected as malicious or abnormal for parameter 11.bias.
# Global Model Test Accuracy after round 5: 90.7500%
# Global Epoch 6/10
# Client 0 has been detected as malicious or abnormal for parameter 0.weight.
# Client 0 has been detected as malicious or abnormal for parameter 3.weight.
# Client 4 has been detected as malicious or abnormal for parameter 3.weight.
# Client 0 has been detected as malicious or abnormal for parameter 3.bias.
# Client 0 has been detected as malicious or abnormal for parameter 7.weight.
# Client 2 has been detected as malicious or abnormal for parameter 7.weight.
# Client 3 has been detected as malicious or abnormal for parameter 7.weight.
# Client 4 has been detected as malicious or abnormal for parameter 7.weight.
# Client 6 has been detected as malicious or abnormal for parameter 7.weight.
# Client 8 has been detected as malicious or abnormal for parameter 7.weight.
# Client 0 has been detected as malicious or abnormal for parameter 7.bias.
# Client 0 has been detected as malicious or abnormal for parameter 9.weight.
# Client 7 has been detected as malicious or abnormal for parameter 9.weight.
# Client 0 has been detected as malicious or abnormal for parameter 9.bias.
# Client 0 has been detected as malicious or abnormal for parameter 11.weight.
# Client 0 has been detected as malicious or abnormal for parameter 11.bias.
# Global Model Test Accuracy after round 6: 91.0100%
# Global Epoch 7/10
# Client 0 has been detected as malicious or abnormal for parameter 0.weight.
# Client 0 has been detected as malicious or abnormal for parameter 0.bias.
# Client 0 has been detected as malicious or abnormal for parameter 3.weight.
# Client 9 has been detected as malicious or abnormal for parameter 3.weight.
# Client 0 has been detected as malicious or abnormal for parameter 3.bias.
# Client 0 has been detected as malicious or abnormal for parameter 7.weight.
# Client 1 has been detected as malicious or abnormal for parameter 7.weight.
# Client 2 has been detected as malicious or abnormal for parameter 7.weight.
# Client 3 has been detected as malicious or abnormal for parameter 7.weight.
# Client 4 has been detected as malicious or abnormal for parameter 7.weight.
# Client 7 has been detected as malicious or abnormal for parameter 7.weight.
# Client 0 has been detected as malicious or abnormal for parameter 7.bias.
# Client 0 has been detected as malicious or abnormal for parameter 9.weight.
# Client 1 has been detected as malicious or abnormal for parameter 9.weight.
# Client 0 has been detected as malicious or abnormal for parameter 9.bias.
# Client 0 has been detected as malicious or abnormal for parameter 11.weight.
# Client 0 has been detected as malicious or abnormal for parameter 11.bias.
# Global Model Test Accuracy after round 7: 93.9900%
# Global Epoch 8/10
# Client 0 has been detected as malicious or abnormal for parameter 0.weight.
# Client 0 has been detected as malicious or abnormal for parameter 3.weight.
# Client 0 has been detected as malicious or abnormal for parameter 3.bias.
# Client 0 has been detected as malicious or abnormal for parameter 7.weight.
# Client 2 has been detected as malicious or abnormal for parameter 7.weight.
# Client 4 has been detected as malicious or abnormal for parameter 7.weight.
# Client 6 has been detected as malicious or abnormal for parameter 7.weight.
# Client 8 has been detected as malicious or abnormal for parameter 7.weight.
# Client 0 has been detected as malicious or abnormal for parameter 7.bias.
# Client 0 has been detected as malicious or abnormal for parameter 9.weight.
# Client 1 has been detected as malicious or abnormal for parameter 9.weight.
# Client 8 has been detected as malicious or abnormal for parameter 9.weight.
# Client 0 has been detected as malicious or abnormal for parameter 9.bias.
# Client 0 has been detected as malicious or abnormal for parameter 11.weight.
# Client 0 has been detected as malicious or abnormal for parameter 11.bias.
# Global Model Test Accuracy after round 8: 91.2500%
# Global Epoch 9/10
# Client 0 has been detected as malicious or abnormal for parameter 0.weight.
# Client 0 has been detected as malicious or abnormal for parameter 0.bias.
# Client 0 has been detected as malicious or abnormal for parameter 3.weight.
# Client 3 has been detected as malicious or abnormal for parameter 3.weight.
# Client 0 has been detected as malicious or abnormal for parameter 3.bias.
# Client 0 has been detected as malicious or abnormal for parameter 7.weight.
# Client 2 has been detected as malicious or abnormal for parameter 7.weight.
# Client 4 has been detected as malicious or abnormal for parameter 7.weight.
# Client 6 has been detected as malicious or abnormal for parameter 7.weight.
# Client 8 has been detected as malicious or abnormal for parameter 7.weight.
# Client 0 has been detected as malicious or abnormal for parameter 7.bias.
# Client 0 has been detected as malicious or abnormal for parameter 9.weight.
# Client 1 has been detected as malicious or abnormal for parameter 9.weight.
# Client 4 has been detected as malicious or abnormal for parameter 9.weight.
# Client 0 has been detected as malicious or abnormal for parameter 9.bias.
# Client 0 has been detected as malicious or abnormal for parameter 11.weight.
# Client 0 has been detected as malicious or abnormal for parameter 11.bias.
# Global Model Test Accuracy after round 9: 92.3600%
# Global Epoch 10/10
# Client 0 has been detected as malicious or abnormal for parameter 0.weight.
# Client 0 has been detected as malicious or abnormal for parameter 0.bias.
# Client 0 has been detected as malicious or abnormal for parameter 3.weight.
# Client 4 has been detected as malicious or abnormal for parameter 3.weight.
# Client 0 has been detected as malicious or abnormal for parameter 3.bias.
# Client 0 has been detected as malicious or abnormal for parameter 7.weight.
# Client 2 has been detected as malicious or abnormal for parameter 7.weight.
# Client 4 has been detected as malicious or abnormal for parameter 7.weight.
# Client 5 has been detected as malicious or abnormal for parameter 7.weight.
# Client 6 has been detected as malicious or abnormal for parameter 7.weight.
# Client 8 has been detected as malicious or abnormal for parameter 7.weight.
# Client 0 has been detected as malicious or abnormal for parameter 7.bias.
# Client 0 has been detected as malicious or abnormal for parameter 9.weight.
# Client 2 has been detected as malicious or abnormal for parameter 9.weight.
# Client 3 has been detected as malicious or abnormal for parameter 9.weight.
# Client 4 has been detected as malicious or abnormal for parameter 9.weight.
# Client 8 has been detected as malicious or abnormal for parameter 9.weight.
# Client 0 has been detected as malicious or abnormal for parameter 9.bias.
# Client 0 has been detected as malicious or abnormal for parameter 11.weight.
# Client 0 has been detected as malicious or abnormal for parameter 11.bias.
# Global Model Test Accuracy after round 10: 89.9100%
# Federated learning process completed.

# %%
# Plot global accuracy

plt.figure(figsize=(8,5))
plt.plot(range(1, global_epochs+1), global_accuracies, marker='o')
plt.title("Global Model Accuracy Across Federated Rounds")
plt.xlabel("Global Epoch")
plt.ylabel("Test Accuracy (%)")
plt.grid(True)
plt.show()

# Plot client losses
plt.figure(figsize=(10,6))
for client_idx in range(n_clients):
    # Flatten nested list of losses per global round
    client_curve = [
    loss for round_losses in client_losses_history[client_idx] if round_losses is not None
    for loss in round_losses
]
    plt.plot(client_curve, label=f'Client {client_idx+1}')
plt.title("Client Training Losses Across Local Epochs")
plt.xlabel("Local Epochs (stacked across global rounds)")
plt.ylabel("Loss")
plt.legend()
plt.grid(True)
plt.show()

# %%
# loading best model
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
state_dict = torch.load('malicious_client_federated_model.pth', weights_only=True)
global_model.load_state_dict(state_dict)

global_model.eval()
global_model.to(device)

# testing saved best model
accuracy = test_model(global_model, test_loader, device)

print("Accuracy of the loaded model：", accuracy)
# Out:
# Accuracy of the loaded model： 89.91

# %%
# Federated Learning process

n_clients=10
global_epochs=10
local_epochs=3
evil_clients = 7


device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Set up the data transformation and load dataset

transform = transforms.Compose(
    [transforms.ToTensor(), transforms.Normalize((0.5,), (0.5,))])

train_dataset, test_dataset = load_data(transform)

plt.imshow(train_dataset[0][0][0], cmap='gray')
plt.show()

# Partition the dataset for each client
client_datasets = partition_dataset(train_dataset, n_clients)
client_loaders = [DataLoader(dataset, batch_size=50, shuffle=True)
                  for dataset in client_datasets]
test_loader = DataLoader(test_dataset, batch_size=1000, shuffle=False)

# Initialize global model and client models
global_model = create_lenet().to(device)
client_models = [copy.deepcopy(global_model) for _ in range(n_clients)]

# Optimizers for client models
optimizers = [torch.optim.Adam(model.parameters(), lr=0.001)
              for model in client_models]

# Federated Learning process
global_accuracies = []
client_losses_history = [[] for _ in range(n_clients)]

for global_epoch in range(global_epochs):
    print(f'Global Epoch {global_epoch + 1}/{global_epochs}')

    # Each client trains locally
    for client_idx in range(n_clients):
      if client_idx < evil_clients:
        losses = evil_client_update(client_models[client_idx])
        client_losses_history[client_idx].append(losses)
      else:
        losses = client_update(client_models[client_idx], optimizers[client_idx],
                      client_loaders[client_idx], device, local_epochs)
        client_losses_history[client_idx].append(losses)


    # Server aggregates the models
    server_aggregate(global_model, client_models)

    # Evaluate global model on test dataset
    test_accuracy = test_model(global_model, test_loader, device)
    global_accuracies.append(test_accuracy)
    print(
        f'Global Model Test Accuracy after round {global_epoch + 1}: {test_accuracy:.4f}%')

print("Federated learning process completed.")
# Out:
# Global Epoch 1/10
# Client 1 has been detected as malicious or abnormal for parameter 7.weight.
# Client 3 has been detected as malicious or abnormal for parameter 7.weight.
# Global Model Test Accuracy after round 1: 9.8900%
# Global Epoch 2/10
# Client 4 has been detected as malicious or abnormal for parameter 7.weight.
# Global Model Test Accuracy after round 2: 9.3100%
# Global Epoch 3/10
# Client 3 has been detected as malicious or abnormal for parameter 7.weight.
# Client 6 has been detected as malicious or abnormal for parameter 7.weight.
# Global Model Test Accuracy after round 3: 9.7400%
# Global Epoch 4/10
# Client 0 has been detected as malicious or abnormal for parameter 7.weight.
# Client 2 has been detected as malicious or abnormal for parameter 9.weight.
# Global Model Test Accuracy after round 4: 3.2300%
# Global Epoch 5/10
# Client 4 has been detected as malicious or abnormal for parameter 3.weight.
# Global Model Test Accuracy after round 5: 8.5700%
# Global Epoch 6/10
# Client 4 has been detected as malicious or abnormal for parameter 7.weight.
# Client 6 has been detected as malicious or abnormal for parameter 7.weight.
# Client 6 has been detected as malicious or abnormal for parameter 9.weight.
# Global Model Test Accuracy after round 6: 11.8200%
# Global Epoch 7/10
# Client 1 has been detected as malicious or abnormal for parameter 7.weight.
# Client 2 has been detected as malicious or abnormal for parameter 7.weight.
# Client 6 has been detected as malicious or abnormal for parameter 7.weight.
# Client 2 has been detected as malicious or abnormal for parameter 9.weight.
# Global Model Test Accuracy after round 7: 7.1200%
# Global Epoch 8/10
# Client 1 has been detected as malicious or abnormal for parameter 9.weight.
# Global Model Test Accuracy after round 8: 10.7600%
# Global Epoch 9/10
# Client 2 has been detected as malicious or abnormal for parameter 7.weight.
# Client 4 has been detected as malicious or abnormal for parameter 7.weight.
# Global Model Test Accuracy after round 9: 9.5400%
# Global Epoch 10/10
# Client 3 has been detected as malicious or abnormal for parameter 7.weight.
# Client 6 has been detected as malicious or abnormal for parameter 7.weight.
# Client 6 has been detected as malicious or abnormal for parameter 9.weight.
# Global Model Test Accuracy after round 10: 8.3800%
# Federated learning process completed.

# %%
# Plot global accuracy

plt.figure(figsize=(8,5))
plt.plot(range(1, global_epochs+1), global_accuracies, marker='o')
plt.title("Global Model Accuracy Across Federated Rounds with 7 Malicious clients")
plt.xlabel("Global Epoch")
plt.ylabel("Test Accuracy (%)")
plt.grid(True)
plt.show()

# Plot client losses
plt.figure(figsize=(10,6))
for client_idx in range(n_clients):
    # Flatten nested list of losses per global round
    client_curve = [
    loss for round_losses in client_losses_history[client_idx] if round_losses is not None
    for loss in round_losses
]
    plt.plot(client_curve, label=f'Client {client_idx+1}')
plt.title("Client Training Losses Across Local Epochs")
plt.xlabel("Local Epochs (stacked across global rounds)")
plt.ylabel("Loss")
plt.legend()
plt.grid(True)
plt.show()

# %%
# testing saved best model
accuracy = test_model(global_model, test_loader, device)

print("Accuracy of the loaded model：", accuracy)
# Out:
# Accuracy of the loaded model： 8.38
